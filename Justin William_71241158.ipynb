# %%
#contoh
print("Ini adalah bentuk print")
# Out:
# Ini adalah bentuk print

# %%
#Menghitung usia
tahunkelahiran = int(input('Tahun kelahiran anda?:'))
tahunhariini = int(input('Sekarang adalah tahun?:'))
usiahariini = tahunhariini - tahunkelahiran
print('Usia anda Sekarang adalah :', usiahariini, 'Tahun')
tanya = int(input('Masukkan umur yang anda ingin ketahui tahunnya:'))
depan = tanya + tahunkelahiran
print("Tahun pada saat anda berusia ", tanya, "tahun adalah, Tahun", depan)
# Out:
# Tahun kelahiran anda?: 2000
# Sekarang adalah tahun?: 2005
# Usia anda Sekarang adalah : 5 Tahun
# Masukkan umur yang anda ingin ketahui tahunnya: 35
# Tahun pada saat anda berusia  35 tahun adalah, Tahun 2035

# %%
#Compound Interest
#Saldo Tahun Satu
saldoawal = 5000000
bungatahunsatu = 0.1 * saldoawal
saldoakhirtahunsatu = saldoawal + bungatahunsatu
print("Saldo akhir tahun pertama:", saldoakhirtahunsatu)
#Saldo Tahun Dua
bungatahundua = 0.1 * saldotahunsatu
saldoakhirtahundua = saldoakhirtahunsatu + bungatahundua
print("Saldo akhir tahun kedua:", saldotahundua)
#Saldo Akhir
bungaakhir = 0.1 * saldotahundua
saldoakhir = saldotahundua + bungaakhir
print("Total saldo terakhir adalah:", saldoakhir)
# Out:
# Saldo tahun pertama: 5500000.0
# Saldo tahun kedua: 6050000.0
# Total saldo adalah: 6655000.0

# %%
#Compound Interest 2
saldoawal = 5000000
besarbunga = 0.1
berapakalisetahun = 1
periode = 3
saldoakhir = saldoawal * (1  + besarbunga/berapakalisetahun) ** (berapakalisetahun*periode)
print("Total saldo adalah:", saldoakhir)
# Out:
# Total saldo adalah: 6655000.000000002

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10)
y_sin = np.sin(x)
z_cos = np.cos(x)

plt.plot(x, y_sin, 'b')
plt.plot(x, y_cos, 'r')
plt.xlabel('Radians');
plt.ylabel('Value');
plt.title('Plotting Demonstratrion')
plt.legend(['sin', 'cos'])
plt.grid()
plt.show()

# %%
#Latihan 1.2
#Soal pertama
gram1 = 25
beli1 = 650_000
jual1 = 685_000

totalbiaya1 = gram1 * beli1
nilaitotal1 = gram1 * jual1
keuntungan1 = nilaitotal1 - totalbiaya1
untungpersen1 = (keuntungan1 / totalbiaya1) * 100
print("Soal pertama")
print(f"Keuntungan (Rp): {keuntungan1:,.2f}")
print(f"Keuntungan (%): {untungpersen1:.2f}%")

#Soal kedua
gram2 = 15
beli2 = 685_000
jual2 = 715_000

totalbiaya2 = gram2 * beli2
biayasemua = totalbiaya1 + totalbiaya2
gramseluruh = gram1 + gram2
nilaitotal2 = total_gram * jual2
keuntungan2 = nilaitotal2 - biayasemua
untungpersen2 = (keuntungan1 / biayasemua) * 100
print("Soal kedua")
print(f"Keuntungan (Rp): {keuntungan2:,.2f}")
print(f"Keuntungan (%): {untungpersen2:.2f}%")
# Out:
# Soal pertama
# Keuntungan (Rp): 875,000.00
# Keuntungan (%): 5.38%
# Soal kedua
# Keuntungan (Rp): 2,075,000.00
# Keuntungan (%): 3.30%

# %%
#Latihan 1.3
import math
jumlahawal = 200000000
jumlahtarget = 400000000
bunga = 0.1       
periode = 1
t = (math.log(jumlahtarget / jumlahawal)) / (periode *math.log(1 + bunga / periode))
print(f"Waktu yang dibutuhkan: {t:.2f} tahun")
# Out:
# Waktu yang dibutuhkan: 7.273 tahun

# %%
#Latihan 1.3 tanpa menggunakan fungsi math.log
saldoawal = 200000000
saldotarget = 400000000
besarbunga = 0.1
berapakalisetahun = 1
periode = 7.27
saldoakhir = saldoawal * (1  + besarbunga/berapakalisetahun) ** (berapakalisetahun*periode)
print("Total saldo adalah:", saldoakhir)
# Out:
# Total saldo adalah: 399903142.37564147
